# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns  # 添加這行
import cv2
import os


dataset_path = 'fer2013'
train_dir = os.path.join(dataset_path, 'train')
test_dir = os.path.join(dataset_path, 'test')

# Step 3: Data preprocessing
# Data Generator
train_datagen = ImageDataGenerator(rescale=1./255, rotation_range=30, zoom_range=0.2, shear_range=0.2, 
                                   horizontal_flip=True, fill_mode='nearest')
test_datagen = ImageDataGenerator(rescale=1./255)

# Create data generators for training and testing sets
train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=(48, 48), batch_size=64, color_mode='rgb', class_mode='categorical'
)
test_generator = test_datagen.flow_from_directory(
    test_dir, target_size=(48, 48), batch_size=64, color_mode='rgb', class_mode='categorical'
)

# 加載預訓練模型
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(48, 48, 3))

# 凍結預訓練層
for layer in base_model.layers:
    layer.trainable = False

# 添加新的分類層
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(7, activation='softmax')(x)

# 建立模型
model = Model(inputs=base_model.input, outputs=predictions)

# 編譯模型
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# Step 5: Train model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=20,
    validation_data=test_generator,
    validation_steps=test_generator.samples // test_generator.batch_size
)

# Step 6: Evaluate model
loss, accuracy = model.evaluate(test_generator)
print(f"Test Accuracy: {accuracy:.4f}")

# Step 7: Plot training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Model Loss')
plt.show()

# Step 8: Predictions and confusion matrix
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_generator.classes

print("Classification Report:")
print(classification_report(y_true, y_pred_classes, target_names=test_generator.class_indices.keys()))

conf_mat = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', 
            xticklabels=test_generator.class_indices.keys(), 
            yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Step 9: Real-time emotion detection (using camera)
def emotion_detection_from_camera():
    cap = cv2.VideoCapture(0)
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
        faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.3, minNeighbors=5)

        for (x, y, w, h) in faces:
            roi_gray = gray_frame[y:y + h, x:x + w]
            roi_gray = cv2.resize(roi_gray, (48, 48))
            roi_gray = roi_gray.astype('float32') / 255.0
            roi_gray = np.expand_dims(roi_gray, axis=0)
            roi_gray = np.expand_dims(roi_gray, axis=-1)
            
            prediction = model.predict(roi_gray)
            emotion_label = test_generator.class_indices.keys()[np.argmax(prediction)]
            cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)
            cv2.putText(frame, emotion_label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        
        cv2.imshow('Emotion Detection', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 48, 48, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 48, 48, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 48, 48, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 24, 24, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 3, 3, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 1, 1, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,781,255 (56.39 MB)
#  Trainable params: 66,567 (260.03 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# Epoch 1/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 231s 514ms/step - accuracy: 0.2710 - loss: 1.8120 - val_accuracy: 0.3482 - val_loss: 1.6356
# Epoch 2/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 323us/step - accuracy: 0.3594 - loss: 1.7226 - val_accuracy: 0.2000 - val_loss: 1.5949
# Epoch 3/20
# c:\Users\hoisaline\AppData\Local\Programs\Python\Python310\lib\contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 226s 505ms/step - accuracy: 0.3208 - loss: 1.6915 - val_accuracy: 0.3677 - val_loss: 1.6165
# Epoch 4/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 252us/step - accuracy: 0.2656 - loss: 1.7299 - val_accuracy: 0.4000 - val_loss: 1.3767
# Epoch 5/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 232s 517ms/step - accuracy: 0.3425 - loss: 1.6632 - val_accuracy: 0.3730 - val_loss: 1.5991
# Epoch 6/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 260us/step - accuracy: 0.4062 - loss: 1.4989 - val_accuracy: 0.5000 - val_loss: 1.3703
# Epoch 7/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 233s 519ms/step - accuracy: 0.3494 - loss: 1.6502 - val_accuracy: 0.3768 - val_loss: 1.5845
# Epoch 8/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 258us/step - accuracy: 0.2969 - loss: 1.6855 - val_accuracy: 0.2000 - val_loss: 1.5250
# Epoch 9/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 228s 510ms/step - accuracy: 0.3538 - loss: 1.6453 - val_accuracy: 0.3806 - val_loss: 1.5794
# Epoch 10/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 245us/step - accuracy: 0.3281 - loss: 1.7498 - val_accuracy: 0.3000 - val_loss: 1.6528
# Epoch 11/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 230s 513ms/step - accuracy: 0.3573 - loss: 1.6277 - val_accuracy: 0.3955 - val_loss: 1.5620
# Epoch 12/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 327us/step - accuracy: 0.3906 - loss: 1.5263 - val_accuracy: 0.2000 - val_loss: 1.8608
# Epoch 13/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 231s 516ms/step - accuracy: 0.3579 - loss: 1.6303 - val_accuracy: 0.3890 - val_loss: 1.5664
# Epoch 14/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 256us/step - accuracy: 0.3438 - loss: 1.6281 - val_accuracy: 0.4000 - val_loss: 1.4442
# Epoch 15/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 230s 513ms/step - accuracy: 0.3649 - loss: 1.6176 - val_accuracy: 0.3895 - val_loss: 1.5619
# Epoch 16/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 241us/step - accuracy: 0.2969 - loss: 1.6267 - val_accuracy: 0.5000 - val_loss: 1.3500
# Epoch 17/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 227s 508ms/step - accuracy: 0.3587 - loss: 1.6168 - val_accuracy: 0.3980 - val_loss: 1.5566
# Epoch 18/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 244us/step - accuracy: 0.4219 - loss: 1.5061 - val_accuracy: 0.4000 - val_loss: 1.3539
# Epoch 19/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 233s 521ms/step - accuracy: 0.3627 - loss: 1.6122 - val_accuracy: 0.3989 - val_loss: 1.5498
# Epoch 20/20
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 262us/step - accuracy: 0.3281 - loss: 1.6064 - val_accuracy: 0.1000 - val_loss: 1.7022
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 46s 403ms/step - accuracy: 0.4051 - loss: 1.5389
# Test Accuracy: 0.3983
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 46s 402ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.15      0.04      0.07       958
#      disgust       0.00      0.00      0.00       111
#         fear       0.17      0.08      0.11      1024
#        happy       0.25      0.42      0.31      1774
#      neutral       0.18      0.25      0.21      1233
#          sad       0.15      0.10      0.12      1247
#     surprise       0.10      0.11      0.10       831
#
#     accuracy                           0.19      7178
#    macro avg       0.14      0.14      0.13      7178
# weighted avg       0.17      0.19      0.17      7178
# c:\Users\hoisaline\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\hoisaline\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\hoisaline\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

# 多輸入模型
input_layer = Input(shape=(48, 48, 1))

# 共用特徵提取層
x = Conv2D(32, (3, 3), activation='relu')(input_layer)
x = MaxPooling2D((2, 2))(x)
x = Flatten()(x)

# 主任務（情緒分類）
emotion_output = Dense(7, activation='softmax', name='emotion_output')(x)

# 輔助任務（性別分類）
gender_output = Dense(2, activation='softmax', name='gender_output')(x)

# 定義多任務模型
model = Model(inputs=input_layer, outputs=[emotion_output, gender_output])

# 編譯模型
model.compile(
    optimizer='adam',
    loss={'emotion_output': 'categorical_crossentropy', 'gender_output': 'categorical_crossentropy'},
    metrics={'emotion_output': 'accuracy', 'gender_output': 'accuracy'}
)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 48, 48, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 46, 46,    │        320 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 23, 23,    │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 16928)     │          0 │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ emotion_output      │ (None, 7)         │    118,503 │ flatten[0][0]     │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_output       │ (None, 2)         │     33,858 │ flatten[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 152,681 (596.41 KB)
#  Trainable params: 152,681 (596.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow.keras.backend as K

def focal_loss(gamma=2., alpha=0.25):
    def loss(y_true, y_pred):
        y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
        pt = K.sum(y_true * y_pred, axis=-1)
        return -K.mean(alpha * K.pow(1 - pt, gamma) * K.log(pt))
    return loss

model.compile(optimizer='adam', loss=focal_loss(), metrics=['accuracy'])

# %%
import tensorflow_hub as hub
from tensorflow.keras.layers import Input

input_layer = Input(shape=(48, 48, 3))
base_model = hub.KerasLayer("https://tfhub.dev/google/vit_base_patch16_224/1", trainable=False)(input_layer)
output_layer = Dense(7, activation='softmax')(base_model)

model = Model(inputs=input_layer, outputs=output_layer)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 import tensorflow_hub as hub
#       2 from tensorflow.keras.layers import Input
#       4 input_layer = Input(shape=(48, 48, 3))
#
# ModuleNotFoundError: No module named 'tensorflow_hub'

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Reshape, multiply

def se_block(input_tensor, ratio=16):
    channel = input_tensor.shape[-1]
    se_shape = (1, 1, channel)
    se = GlobalAveragePooling2D()(input_tensor)
    se = Reshape(se_shape)(se)
    se = Dense(channel // ratio, activation='relu', use_bias=False)(se)
    se = Dense(channel, activation='sigmoid', use_bias=False)(se)
    return multiply([input_tensor, se])

# 添加 SE 模塊到模型
x = Conv2D(128, (3, 3), activation='relu')(previous_layer)
x = se_block(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 13
#      10     return multiply([input_tensor, se])
#      12 # 添加 SE 模塊到模型
# ---> 13 x = Conv2D(128, (3, 3), activation='relu')(previous_layer)
#      14 x = se_block(x)
#
# NameError: name 'previous_layer' is not defined

# %%
from tensorflow.keras.layers import ConvLSTM2D

# 使用 ConvLSTM2D 處理時間序列
model = Sequential([
    ConvLSTM2D(32, (3, 3), activation='relu', input_shape=(10, 48, 48, 1)),  # 10 為時間序列長度
    Flatten(),
    Dense(128, activation='relu'),
    Dense(7, activation='softmax')
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 4
#       1 from tensorflow.keras.layers import ConvLSTM2D
#       3 # 使用 ConvLSTM2D 處理時間序列
# ----> 4 model = Sequential([
#       5     ConvLSTM2D(32, (3, 3), activation='relu', input_shape=(10, 48, 48, 1)),  # 10 為時間序列長度
#       6     Flatten(),
#       7     Dense(128, activation='relu'),
#       8     Dense(7, activation='softmax')
#       9 ])
#
# NameError: name 'Sequential' is not defined
